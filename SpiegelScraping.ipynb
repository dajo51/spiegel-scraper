# %%
from bs4 import BeautifulSoup
import urllib.request
import time as t
import json
import csv

# %%
issues_links = []
article_list = []

for year in range(2000, 2022):
    for issue in range(1, 52):
        issues_links.append(f"https://www.spiegel.de/spiegel/print/index-{year}-{issue}.html")
        
for issue in issues_links:
    with urllib.request.urlopen(issue) as response:
       html = response.read()
    
    # get all article links and titles, then choose amount of articles to scrape
    soup = BeautifulSoup(html, 'html.parser')
    for a in soup.findAll("article"):
        link = a.find("a")
        article_list.append([link["href"], link["title"]])
        
    # article_list = article_list[:100]

    print("Issue added! Time needed to scrape articles:", round((5*len(article_list)/60), 2), "minutes")
    print("Total articles:", len(article_list))
    t.sleep(5)
# Out:
# Issue added! Time needed to scrape issue: 9.92 minutes
# 119
# Issue added! Time needed to scrape issue: 20.0 minutes
# 240
# Issue added! Time needed to scrape issue: 30.25 minutes
# 363
# Issue added! Time needed to scrape issue: 41.5 minutes
# 498
# Issue added! Time needed to scrape issue: 52.33 minutes
# 628
# Issue added! Time needed to scrape issue: 63.17 minutes
# 758
# Issue added! Time needed to scrape issue: 72.83 minutes
# 874
# Issue added! Time needed to scrape issue: 86.33 minutes
# 1036
# Issue added! Time needed to scrape issue: 98.0 minutes
# 1176
# Issue added! Time needed to scrape issue: 108.33 minutes
# 1300
# Issue added! Time needed to scrape issue: 119.75 minutes
# 1437
# Issue added! Time needed to scrape issue: 130.75 minutes
# 1569
# Issue added! Time needed to scrape issue: 142.25 minutes
# 1707
# Issue added! Time needed to scrape issue: 152.92 minutes
# 1835
# Issue added! Time needed to scrape issue: 163.83 minutes
# 1966
# Issue added! Time needed to scrape issue: 174.58 minutes
# 2095
# Issue added! Time needed to scrape issue: 185.83 minutes
# 2230
# Issue added! Time needed to scrape issue: 196.58 minutes
# 2359
# Issue added! Time needed to scrape issue: 207.42 minutes
# 2489
# Issue added! Time needed to scrape issue: 217.67 minutes
# 2612
# Issue added! Time needed to scrape issue: 229.58 minutes
# 2755
# Issue added! Time needed to scrape issue: 240.83 minutes
# 2890
# Issue added! Time needed to scrape issue: 251.25 minutes
# 3015
# Issue added! Time needed to scrape issue: 262.67 minutes
# 3152
# Issue added! Time needed to scrape issue: 273.33 minutes
# 3280
# Issue added! Time needed to scrape issue: 283.17 minutes
# 3398
# Issue added! Time needed to scrape issue: 293.92 minutes
# 3527
# Issue added! Time needed to scrape issue: 304.75 minutes
# 3657
# Issue added! Time needed to scrape issue: 315.08 minutes
# 3781
# Issue added! Time needed to scrape issue: 325.25 minutes
# 3903
# Issue added! Time needed to scrape issue: 335.42 minutes
# 4025
# Issue added! Time needed to scrape issue: 345.92 minutes
# 4151
# Issue added! Time needed to scrape issue: 356.83 minutes
# 4282
# Issue added! Time needed to scrape issue: 367.17 minutes
# 4406
# Issue added! Time needed to scrape issue: 377.92 minutes
# 4535
# Issue added! Time needed to scrape issue: 388.33 minutes
# 4660
# Issue added! Time needed to scrape issue: 399.5 minutes
# 4794
# Issue added! Time needed to scrape issue: 410.83 minutes
# 4930
# Issue added! Time needed to scrape issue: 422.25 minutes
# 5067
# Issue added! Time needed to scrape issue: 434.42 minutes
# 5213
# Issue added! Time needed to scrape issue: 445.42 minutes
# 5345
# Issue added! Time needed to scrape issue: 457.92 minutes
# 5495
# Issue added! Time needed to scrape issue: 470.17 minutes
# 5642
# Issue added! Time needed to scrape issue: 482.92 minutes
# 5795
# Issue added! Time needed to scrape issue: 495.5 minutes
# 5946
# Issue added! Time needed to scrape issue: 507.08 minutes
# 6085
# Issue added! Time needed to scrape issue: 519.42 minutes
# 6233
# Issue added! Time needed to scrape issue: 531.08 minutes
# 6373
# Issue added! Time needed to scrape issue: 541.5 minutes
# 6498
# Issue added! Time needed to scrape issue: 552.5 minutes
# 6630
# Issue added! Time needed to scrape issue: 562.75 minutes
# 6753
# Issue added! Time needed to scrape issue: 571.83 minutes
# 6862
# Issue added! Time needed to scrape issue: 581.42 minutes
# 6977
# Issue added! Time needed to scrape issue: 590.92 minutes
# 7091
# Issue added! Time needed to scrape issue: 601.42 minutes
# 7217
# Issue added! Time needed to scrape issue: 611.33 minutes
# 7336
# Issue added! Time needed to scrape issue: 621.42 minutes
# 7457
# Issue added! Time needed to scrape issue: 632.08 minutes
# 7585
# Issue added! Time needed to scrape issue: 642.25 minutes
# 7707
# Issue added! Time needed to scrape issue: 651.83 minutes
# 7822
# Issue added! Time needed to scrape issue: 662.08 minutes
# 7945
# Issue added! Time needed to scrape issue: 672.75 minutes
# 8073
# Issue added! Time needed to scrape issue: 686.5 minutes
# 8238
# Issue added! Time needed to scrape issue: 696.83 minutes
# 8362
# Issue added! Time needed to scrape issue: 706.83 minutes
# 8482
# Issue added! Time needed to scrape issue: 717.17 minutes
# 8606
# Issue added! Time needed to scrape issue: 726.75 minutes
# 8721
# Issue added! Time needed to scrape issue: 737.25 minutes
# 8847
# Issue added! Time needed to scrape issue: 747.42 minutes
# 8969
# Issue added! Time needed to scrape issue: 758.17 minutes
# 9098
# Issue added! Time needed to scrape issue: 769.42 minutes
# 9233
# Issue added! Time needed to scrape issue: 779.67 minutes
# 9356
# Issue added! Time needed to scrape issue: 790.17 minutes
# 9482
# Issue added! Time needed to scrape issue: 800.67 minutes
# 9608
# Issue added! Time needed to scrape issue: 811.5 minutes
# 9738
# Issue added! Time needed to scrape issue: 821.83 minutes
# 9862
# Issue added! Time needed to scrape issue: 832.5 minutes
# 9990
# Issue added! Time needed to scrape issue: 843.08 minutes
# 10117
# Issue added! Time needed to scrape issue: 853.17 minutes
# 10238
# Issue added! Time needed to scrape issue: 863.83 minutes
# 10366
# Issue added! Time needed to scrape issue: 874.25 minutes
# 10491
# Issue added! Time needed to scrape issue: 884.33 minutes
# 10612
# Issue added! Time needed to scrape issue: 894.08 minutes
# 10729
# Issue added! Time needed to scrape issue: 904.42 minutes
# 10853
# Issue added! Time needed to scrape issue: 914.75 minutes
# 10977
# Issue added! Time needed to scrape issue: 925.08 minutes
# 11101
# Issue added! Time needed to scrape issue: 935.75 minutes
# 11229
# Issue added! Time needed to scrape issue: 946.08 minutes
# 11353
# Issue added! Time needed to scrape issue: 956.42 minutes
# 11477
# Issue added! Time needed to scrape issue: 964.42 minutes
# 11573
# Issue added! Time needed to scrape issue: 974.17 minutes
# 11690
# Issue added! Time needed to scrape issue: 985.25 minutes
# 11823
# Issue added! Time needed to scrape issue: 996.0 minutes
# 11952
# Issue added! Time needed to scrape issue: 1005.33 minutes
# 12064
# Issue added! Time needed to scrape issue: 1015.5 minutes
# 12186
# Issue added! Time needed to scrape issue: 1025.25 minutes
# 12303
# Issue added! Time needed to scrape issue: 1034.25 minutes
# 12411
# Issue added! Time needed to scrape issue: 1044.33 minutes
# 12532
# Issue added! Time needed to scrape issue: 1054.92 minutes
# 12659
# Issue added! Time needed to scrape issue: 1064.42 minutes
# 12773
# Issue added! Time needed to scrape issue: 1073.33 minutes
# 12880
# Issue added! Time needed to scrape issue: 1081.5 minutes
# 12978
# Issue added! Time needed to scrape issue: 1092.0 minutes
# 13104
# Issue added! Time needed to scrape issue: 1102.0 minutes
# 13224
# Issue added! Time needed to scrape issue: 1111.75 minutes
# 13341
# Issue added! Time needed to scrape issue: 1122.08 minutes
# 13465
# Issue added! Time needed to scrape issue: 1132.83 minutes
# 13594
# Issue added! Time needed to scrape issue: 1142.75 minutes
# 13713
# Issue added! Time needed to scrape issue: 1153.08 minutes
# 13837
# Issue added! Time needed to scrape issue: 1163.42 minutes
# 13961
# Issue added! Time needed to scrape issue: 1173.75 minutes
# 14085
# Issue added! Time needed to scrape issue: 1184.08 minutes
# 14209
# Issue added! Time needed to scrape issue: 1197.0 minutes
# 14364
# Issue added! Time needed to scrape issue: 1207.08 minutes
# 14485
# Issue added! Time needed to scrape issue: 1217.5 minutes
# 14610
# Issue added! Time needed to scrape issue: 1227.5 minutes
# 14730
# Issue added! Time needed to scrape issue: 1236.75 minutes
# 14841
# Issue added! Time needed to scrape issue: 1246.75 minutes
# 14961
# Issue added! Time needed to scrape issue: 1256.75 minutes
# 15081
# Issue added! Time needed to scrape issue: 1265.67 minutes
# 15188
# Issue added! Time needed to scrape issue: 1275.83 minutes
# 15310
# Issue added! Time needed to scrape issue: 1286.25 minutes
# 15435
# Issue added! Time needed to scrape issue: 1296.17 minutes
# 15554
# Issue added! Time needed to scrape issue: 1306.33 minutes
# 15676
# Issue added! Time needed to scrape issue: 1316.67 minutes
# 15800
# Issue added! Time needed to scrape issue: 1326.17 minutes
# 15914
# Issue added! Time needed to scrape issue: 1336.42 minutes
# 16037
# Issue added! Time needed to scrape issue: 1345.83 minutes
# 16150
# Issue added! Time needed to scrape issue: 1355.75 minutes
# 16269
# Issue added! Time needed to scrape issue: 1365.25 minutes
# 16383
# Issue added! Time needed to scrape issue: 1375.75 minutes
# 16509
# Issue added! Time needed to scrape issue: 1386.08 minutes
# 16633
# Issue added! Time needed to scrape issue: 1395.08 minutes
# 16741
# Issue added! Time needed to scrape issue: 1405.0 minutes
# 16860
# Issue added! Time needed to scrape issue: 1415.17 minutes
# 16982
# Issue added! Time needed to scrape issue: 1424.42 minutes
# 17093
# Issue added! Time needed to scrape issue: 1433.92 minutes
# 17207
# Issue added! Time needed to scrape issue: 1442.83 minutes
# 17314
# Issue added! Time needed to scrape issue: 1452.25 minutes
# 17427
# Issue added! Time needed to scrape issue: 1461.42 minutes
# 17537
# Issue added! Time needed to scrape issue: 1470.83 minutes
# 17650
# Issue added! Time needed to scrape issue: 1480.67 minutes
# 17768
# Issue added! Time needed to scrape issue: 1491.17 minutes
# 17894
# Issue added! Time needed to scrape issue: 1501.0 minutes
# 18012
# Issue added! Time needed to scrape issue: 1510.75 minutes
# 18129
# Issue added! Time needed to scrape issue: 1519.75 minutes
# 18237
# Issue added! Time needed to scrape issue: 1529.75 minutes
# 18357
# Issue added! Time needed to scrape issue: 1537.92 minutes
# 18455
# Issue added! Time needed to scrape issue: 1547.42 minutes
# 18569
# Issue added! Time needed to scrape issue: 1557.17 minutes
# 18686
# Issue added! Time needed to scrape issue: 1566.42 minutes
# 18797
# Issue added! Time needed to scrape issue: 1576.58 minutes
# 18919
# Issue added! Time needed to scrape issue: 1586.67 minutes
# 19040
# Issue added! Time needed to scrape issue: 1597.0 minutes
# 19164
# Issue added! Time needed to scrape issue: 1607.0 minutes
# 19284
# Issue added! Time needed to scrape issue: 1616.58 minutes
# 19399
# Issue added! Time needed to scrape issue: 1626.0 minutes
# 19512
# Issue added! Time needed to scrape issue: 1635.08 minutes
# 19621
# Issue added! Time needed to scrape issue: 1644.33 minutes
# 19732
# Issue added! Time needed to scrape issue: 1653.92 minutes
# 19847
# Issue added! Time needed to scrape issue: 1663.0 minutes
# 19956
# Issue added! Time needed to scrape issue: 1672.0 minutes
# 20064
# Issue added! Time needed to scrape issue: 1681.58 minutes
# 20179
# Issue added! Time needed to scrape issue: 1692.75 minutes
# 20313
# Issue added! Time needed to scrape issue: 1703.08 minutes
# 20437
# Issue added! Time needed to scrape issue: 1711.58 minutes
# 20539
# Issue added! Time needed to scrape issue: 1720.75 minutes
# 20649
# Issue added! Time needed to scrape issue: 1730.92 minutes
# 20771
# Issue added! Time needed to scrape issue: 1740.25 minutes
# 20883
# Issue added! Time needed to scrape issue: 1749.0 minutes
# 20988
# Issue added! Time needed to scrape issue: 1758.58 minutes
# 21103
# Issue added! Time needed to scrape issue: 1767.92 minutes
# 21215
# Issue added! Time needed to scrape issue: 1777.17 minutes
# 21326
# Issue added! Time needed to scrape issue: 1785.92 minutes
# 21431
# Issue added! Time needed to scrape issue: 1794.92 minutes
# 21539
# Issue added! Time needed to scrape issue: 1804.75 minutes
# 21657
# Issue added! Time needed to scrape issue: 1814.0 minutes
# 21768
# Issue added! Time needed to scrape issue: 1822.92 minutes
# 21875
# Issue added! Time needed to scrape issue: 1832.17 minutes
# 21986
# Issue added! Time needed to scrape issue: 1841.08 minutes
# 22093
# Issue added! Time needed to scrape issue: 1849.83 minutes
# 22198
# Issue added! Time needed to scrape issue: 1859.0 minutes
# 22308
# Issue added! Time needed to scrape issue: 1867.92 minutes
# 22415
# Issue added! Time needed to scrape issue: 1876.5 minutes
# 22518
# Issue added! Time needed to scrape issue: 1885.0 minutes
# 22620
# Issue added! Time needed to scrape issue: 1893.83 minutes
# 22726
# Issue added! Time needed to scrape issue: 1902.92 minutes
# 22835
# Issue added! Time needed to scrape issue: 1912.58 minutes
# 22951
# Issue added! Time needed to scrape issue: 1920.92 minutes
# 23051
# Issue added! Time needed to scrape issue: 1929.75 minutes
# 23157
# Issue added! Time needed to scrape issue: 1939.58 minutes
# 23275
# Issue added! Time needed to scrape issue: 1948.92 minutes
# 23387
# Issue added! Time needed to scrape issue: 1958.0 minutes
# 23496
# Issue added! Time needed to scrape issue: 1967.83 minutes
# 23614
# Issue added! Time needed to scrape issue: 1977.5 minutes
# 23730
# Issue added! Time needed to scrape issue: 1987.42 minutes
# 23849
# Issue added! Time needed to scrape issue: 1997.75 minutes
# 23973
# Issue added! Time needed to scrape issue: 2008.08 minutes
# 24097
# Issue added! Time needed to scrape issue: 2018.08 minutes
# 24217
# Issue added! Time needed to scrape issue: 2028.33 minutes
# 24340
# Issue added! Time needed to scrape issue: 2038.0 minutes
# 24456
# Issue added! Time needed to scrape issue: 2047.33 minutes
# 24568
# Issue added! Time needed to scrape issue: 2057.17 minutes
# 24686
# Issue added! Time needed to scrape issue: 2067.08 minutes
# 24805
# Issue added! Time needed to scrape issue: 2077.17 minutes
# 24926
# Issue added! Time needed to scrape issue: 2086.17 minutes
# 25034
# Issue added! Time needed to scrape issue: 2095.58 minutes
# 25147
# Issue added! Time needed to scrape issue: 2105.17 minutes
# 25262
# Issue added! Time needed to scrape issue: 2114.08 minutes
# 25369
# Issue added! Time needed to scrape issue: 2123.58 minutes
# 25483
# Issue added! Time needed to scrape issue: 2133.33 minutes
# 25600
# Issue added! Time needed to scrape issue: 2142.75 minutes
# 25713
# Issue added! Time needed to scrape issue: 2151.67 minutes
# 25820
# Issue added! Time needed to scrape issue: 2161.25 minutes
# 25935
# Issue added! Time needed to scrape issue: 2170.17 minutes
# 26042
# Issue added! Time needed to scrape issue: 2180.75 minutes
# 26169
# Issue added! Time needed to scrape issue: 2190.0 minutes
# 26280
# Issue added! Time needed to scrape issue: 2199.58 minutes
# 26395
# Issue added! Time needed to scrape issue: 2209.42 minutes
# 26513
# Issue added! Time needed to scrape issue: 2219.75 minutes
# 26637
# Issue added! Time needed to scrape issue: 2228.58 minutes
# 26743
# Issue added! Time needed to scrape issue: 2237.75 minutes
# 26853
# Issue added! Time needed to scrape issue: 2247.42 minutes
# 26969
# Issue added! Time needed to scrape issue: 2256.0 minutes
# 27072
# Issue added! Time needed to scrape issue: 2265.17 minutes
# 27182
# Issue added! Time needed to scrape issue: 2274.75 minutes
# 27297
# Issue added! Time needed to scrape issue: 2284.67 minutes
# 27416
# Issue added! Time needed to scrape issue: 2294.25 minutes
# 27531
# Issue added! Time needed to scrape issue: 2303.33 minutes
# 27640
# Issue added! Time needed to scrape issue: 2313.08 minutes
# 27757
# Issue added! Time needed to scrape issue: 2323.33 minutes
# 27880
# Issue added! Time needed to scrape issue: 2333.0 minutes
# 27996
# Issue added! Time needed to scrape issue: 2342.42 minutes
# 28109
# Issue added! Time needed to scrape issue: 2351.0 minutes
# 28212
# Issue added! Time needed to scrape issue: 2359.25 minutes
# 28311
# Issue added! Time needed to scrape issue: 2368.0 minutes
# 28416
# Issue added! Time needed to scrape issue: 2376.83 minutes
# 28522
# Issue added! Time needed to scrape issue: 2385.75 minutes
# 28629
# Issue added! Time needed to scrape issue: 2395.5 minutes
# 28746
# Issue added! Time needed to scrape issue: 2404.92 minutes
# 28859
# Issue added! Time needed to scrape issue: 2414.25 minutes
# 28971
# Issue added! Time needed to scrape issue: 2423.17 minutes
# 29078
# Issue added! Time needed to scrape issue: 2432.67 minutes
# 29192
# Issue added! Time needed to scrape issue: 2441.92 minutes
# 29303
# Issue added! Time needed to scrape issue: 2451.92 minutes
# 29423
# Issue added! Time needed to scrape issue: 2461.75 minutes
# 29541
# Issue added! Time needed to scrape issue: 2471.83 minutes
# 29662
# Issue added! Time needed to scrape issue: 2481.33 minutes
# 29776
# Issue added! Time needed to scrape issue: 2490.33 minutes
# 29884
# Issue added! Time needed to scrape issue: 2500.0 minutes
# 30000
# Issue added! Time needed to scrape issue: 2509.67 minutes
# 30116
# Issue added! Time needed to scrape issue: 2519.33 minutes
# 30232
# Issue added! Time needed to scrape issue: 2527.83 minutes
# 30334
# Issue added! Time needed to scrape issue: 2537.67 minutes
# 30452
# Issue added! Time needed to scrape issue: 2547.42 minutes
# 30569
# Issue added! Time needed to scrape issue: 2556.08 minutes
# 30673
# Issue added! Time needed to scrape issue: 2565.5 minutes
# 30786
# Issue added! Time needed to scrape issue: 2574.42 minutes
# 30893
# Issue added! Time needed to scrape issue: 2583.42 minutes
# 31001
# Issue added! Time needed to scrape issue: 2592.92 minutes
# 31115
# Issue added! Time needed to scrape issue: 2601.92 minutes
# 31223
# Issue added! Time needed to scrape issue: 2611.0 minutes
# 31332
# Issue added! Time needed to scrape issue: 2619.83 minutes
# 31438
# Issue added! Time needed to scrape issue: 2628.33 minutes
# 31540
# Issue added! Time needed to scrape issue: 2639.17 minutes
# 31670
# Issue added! Time needed to scrape issue: 2649.33 minutes
# 31792
# Issue added! Time needed to scrape issue: 2658.5 minutes
# 31902
# Issue added! Time needed to scrape issue: 2668.08 minutes
# 32017
# Issue added! Time needed to scrape issue: 2677.17 minutes
# 32126
# Issue added! Time needed to scrape issue: 2686.42 minutes
# 32237
# Issue added! Time needed to scrape issue: 2695.83 minutes
# 32350
# Issue added! Time needed to scrape issue: 2705.5 minutes
# 32466
# Issue added! Time needed to scrape issue: 2714.58 minutes
# 32575
# Issue added! Time needed to scrape issue: 2723.58 minutes
# 32683
# Issue added! Time needed to scrape issue: 2732.92 minutes
# 32795
# Issue added! Time needed to scrape issue: 2742.75 minutes
# 32913
# Issue added! Time needed to scrape issue: 2751.58 minutes
# 33019
# Issue added! Time needed to scrape issue: 2760.83 minutes
# 33130
# Issue added! Time needed to scrape issue: 2769.92 minutes
# 33239
# Issue added! Time needed to scrape issue: 2779.17 minutes
# 33350
# Issue added! Time needed to scrape issue: 2788.25 minutes
# 33459
# Issue added! Time needed to scrape issue: 2797.67 minutes
# 33572
# Issue added! Time needed to scrape issue: 2806.58 minutes
# 33679
# Issue added! Time needed to scrape issue: 2815.33 minutes
# 33784
# Issue added! Time needed to scrape issue: 2824.25 minutes
# 33891
# Issue added! Time needed to scrape issue: 2833.75 minutes
# 34005
# Issue added! Time needed to scrape issue: 2842.58 minutes
# 34111
# Issue added! Time needed to scrape issue: 2851.75 minutes
# 34221
# Issue added! Time needed to scrape issue: 2860.08 minutes
# 34321
# Issue added! Time needed to scrape issue: 2868.83 minutes
# 34426
# Issue added! Time needed to scrape issue: 2877.42 minutes
# 34529
# Issue added! Time needed to scrape issue: 2886.75 minutes
# 34641
# Issue added! Time needed to scrape issue: 2894.75 minutes
# 34737
# Issue added! Time needed to scrape issue: 2904.58 minutes
# 34855
# Issue added! Time needed to scrape issue: 2912.67 minutes
# 34952
# Issue added! Time needed to scrape issue: 2922.58 minutes
# 35071
# Issue added! Time needed to scrape issue: 2933.5 minutes
# 35202
# Issue added! Time needed to scrape issue: 2943.33 minutes
# 35320
# Issue added! Time needed to scrape issue: 2951.58 minutes
# 35419
# Issue added! Time needed to scrape issue: 2960.67 minutes
# 35528
# Issue added! Time needed to scrape issue: 2969.92 minutes
# 35639
# Issue added! Time needed to scrape issue: 2979.08 minutes
# 35749
# Issue added! Time needed to scrape issue: 2988.58 minutes
# 35863
# Issue added! Time needed to scrape issue: 2997.5 minutes
# 35970
# Issue added! Time needed to scrape issue: 3006.75 minutes
# 36081
# Issue added! Time needed to scrape issue: 3016.33 minutes
# 36196
# Issue added! Time needed to scrape issue: 3024.5 minutes
# 36294
# Issue added! Time needed to scrape issue: 3033.5 minutes
# 36402
# Issue added! Time needed to scrape issue: 3043.0 minutes
# 36516
# Issue added! Time needed to scrape issue: 3052.58 minutes
# 36631
# Issue added! Time needed to scrape issue: 3061.83 minutes
# 36742
# Issue added! Time needed to scrape issue: 3071.08 minutes
# 36853
# Issue added! Time needed to scrape issue: 3079.5 minutes
# 36954
# Issue added! Time needed to scrape issue: 3087.92 minutes
# 37055
# Issue added! Time needed to scrape issue: 3097.25 minutes
# 37167
# Issue added! Time needed to scrape issue: 3107.0 minutes
# 37284
# Issue added! Time needed to scrape issue: 3116.33 minutes
# 37396
# Issue added! Time needed to scrape issue: 3125.58 minutes
# 37507
# Issue added! Time needed to scrape issue: 3134.5 minutes
# 37614
# Issue added! Time needed to scrape issue: 3143.0 minutes
# 37716
# Issue added! Time needed to scrape issue: 3152.25 minutes
# 37827
# Issue added! Time needed to scrape issue: 3161.0 minutes
# 37932
# Issue added! Time needed to scrape issue: 3170.08 minutes
# 38041
# Issue added! Time needed to scrape issue: 3179.0 minutes
# 38148
# Issue added! Time needed to scrape issue: 3187.92 minutes
# 38255
# Issue added! Time needed to scrape issue: 3197.33 minutes
# 38368
# Issue added! Time needed to scrape issue: 3206.75 minutes
# 38481
# Issue added! Time needed to scrape issue: 3216.0 minutes
# 38592
# Issue added! Time needed to scrape issue: 3225.17 minutes
# 38702
# Issue added! Time needed to scrape issue: 3234.75 minutes
# 38817
# Issue added! Time needed to scrape issue: 3244.0 minutes
# 38928
# Issue added! Time needed to scrape issue: 3252.92 minutes
# 39035
# Issue added! Time needed to scrape issue: 3262.58 minutes
# 39151
# Issue added! Time needed to scrape issue: 3271.83 minutes
# 39262
# Issue added! Time needed to scrape issue: 3281.0 minutes
# 39372
# Issue added! Time needed to scrape issue: 3290.33 minutes
# 39484
# Issue added! Time needed to scrape issue: 3299.17 minutes
# 39590
# Issue added! Time needed to scrape issue: 3307.75 minutes
# 39693
# Issue added! Time needed to scrape issue: 3316.33 minutes
# 39796
# Issue added! Time needed to scrape issue: 3324.92 minutes
# 39899
# Issue added! Time needed to scrape issue: 3333.75 minutes
# 40005
# Issue added! Time needed to scrape issue: 3343.0 minutes
# 40116
# Issue added! Time needed to scrape issue: 3351.33 minutes
# 40216
# Issue added! Time needed to scrape issue: 3360.5 minutes
# 40326
# Issue added! Time needed to scrape issue: 3369.58 minutes
# 40435
# Issue added! Time needed to scrape issue: 3379.0 minutes
# 40548
# Issue added! Time needed to scrape issue: 3388.33 minutes
# 40660
# Issue added! Time needed to scrape issue: 3397.5 minutes
# 40770
# Issue added! Time needed to scrape issue: 3407.5 minutes
# 40890
# Issue added! Time needed to scrape issue: 3416.33 minutes
# 40996
# Issue added! Time needed to scrape issue: 3425.83 minutes
# 41110
# Issue added! Time needed to scrape issue: 3435.67 minutes
# 41228
# Issue added! Time needed to scrape issue: 3445.33 minutes
# 41344
# Issue added! Time needed to scrape issue: 3454.58 minutes
# 41455
# Issue added! Time needed to scrape issue: 3464.0 minutes
# 41568
# Issue added! Time needed to scrape issue: 3473.75 minutes
# 41685
# Issue added! Time needed to scrape issue: 3483.17 minutes
# 41798
# Issue added! Time needed to scrape issue: 3492.08 minutes
# 41905
# Issue added! Time needed to scrape issue: 3504.58 minutes
# 42055
# Issue added! Time needed to scrape issue: 3513.75 minutes
# 42165
# Issue added! Time needed to scrape issue: 3522.25 minutes
# 42267
# Issue added! Time needed to scrape issue: 3530.75 minutes
# 42369
# Issue added! Time needed to scrape issue: 3540.0 minutes
# 42480
# Issue added! Time needed to scrape issue: 3549.17 minutes
# 42590
# Issue added! Time needed to scrape issue: 3558.5 minutes
# 42702
# Issue added! Time needed to scrape issue: 3567.5 minutes
# 42810
# Issue added! Time needed to scrape issue: 3576.58 minutes
# 42919
# Issue added! Time needed to scrape issue: 3585.67 minutes
# 43028
# Issue added! Time needed to scrape issue: 3595.17 minutes
# 43142
# Issue added! Time needed to scrape issue: 3604.67 minutes
# 43256
# Issue added! Time needed to scrape issue: 3613.58 minutes
# 43363
# Issue added! Time needed to scrape issue: 3622.75 minutes
# 43473
# Issue added! Time needed to scrape issue: 3632.17 minutes
# 43586
# Issue added! Time needed to scrape issue: 3641.83 minutes
# 43702
# Issue added! Time needed to scrape issue: 3650.92 minutes
# 43811
# Issue added! Time needed to scrape issue: 3660.83 minutes
# 43930
# Issue added! Time needed to scrape issue: 3670.83 minutes
# 44050
# Issue added! Time needed to scrape issue: 3680.17 minutes
# 44162
# Issue added! Time needed to scrape issue: 3688.83 minutes
# 44266
# Issue added! Time needed to scrape issue: 3697.67 minutes
# 44372
# Issue added! Time needed to scrape issue: 3707.0 minutes
# 44484
# Issue added! Time needed to scrape issue: 3716.5 minutes
# 44598
# Issue added! Time needed to scrape issue: 3725.75 minutes
# 44709
# Issue added! Time needed to scrape issue: 3734.75 minutes
# 44817
# Issue added! Time needed to scrape issue: 3743.58 minutes
# 44923
# Issue added! Time needed to scrape issue: 3752.67 minutes
# 45032
# Issue added! Time needed to scrape issue: 3761.5 minutes
# 45138
# Issue added! Time needed to scrape issue: 3770.75 minutes
# 45249
# Issue added! Time needed to scrape issue: 3780.17 minutes
# 45362
# Issue added! Time needed to scrape issue: 3788.75 minutes
# 45465
# Issue added! Time needed to scrape issue: 3798.42 minutes
# 45581
# Issue added! Time needed to scrape issue: 3807.33 minutes
# 45688
# Issue added! Time needed to scrape issue: 3817.0 minutes
# 45804
# Issue added! Time needed to scrape issue: 3825.92 minutes
# 45911
# Issue added! Time needed to scrape issue: 3835.5 minutes
# 46026
# Issue added! Time needed to scrape issue: 3845.33 minutes
# 46144
# Issue added! Time needed to scrape issue: 3855.42 minutes
# 46265
# Issue added! Time needed to scrape issue: 3865.25 minutes
# 46383
# Issue added! Time needed to scrape issue: 3875.25 minutes
# 46503
# Issue added! Time needed to scrape issue: 3884.33 minutes
# 46612
# Issue added! Time needed to scrape issue: 3893.17 minutes
# 46718
# Issue added! Time needed to scrape issue: 3902.67 minutes
# 46832
# Issue added! Time needed to scrape issue: 3912.58 minutes
# 46951
# Issue added! Time needed to scrape issue: 3922.75 minutes
# 47073
# Issue added! Time needed to scrape issue: 3932.33 minutes
# 47188
# Issue added! Time needed to scrape issue: 3943.42 minutes
# 47321
# Issue added! Time needed to scrape issue: 3952.42 minutes
# 47429
# Issue added! Time needed to scrape issue: 3961.67 minutes
# 47540
# Issue added! Time needed to scrape issue: 3971.92 minutes
# 47663
# Issue added! Time needed to scrape issue: 3980.75 minutes
# 47769
# Issue added! Time needed to scrape issue: 3990.33 minutes
# 47884
# Issue added! Time needed to scrape issue: 3999.25 minutes
# 47991
# Issue added! Time needed to scrape issue: 4008.58 minutes
# 48103
# Issue added! Time needed to scrape issue: 4018.17 minutes
# 48218
# Issue added! Time needed to scrape issue: 4027.5 minutes
# 48330
# Issue added! Time needed to scrape issue: 4036.5 minutes
# 48438
# Issue added! Time needed to scrape issue: 4045.5 minutes
# 48546
# Issue added! Time needed to scrape issue: 4054.5 minutes
# 48654
# Issue added! Time needed to scrape issue: 4063.58 minutes
# 48763
# Issue added! Time needed to scrape issue: 4072.67 minutes
# 48872
# Issue added! Time needed to scrape issue: 4081.33 minutes
# 48976
# Issue added! Time needed to scrape issue: 4089.83 minutes
# 49078
# Issue added! Time needed to scrape issue: 4099.5 minutes
# 49194
# Issue added! Time needed to scrape issue: 4107.75 minutes
# 49293
# Issue added! Time needed to scrape issue: 4116.33 minutes
# 49396
# Issue added! Time needed to scrape issue: 4125.08 minutes
# 49501
# Issue added! Time needed to scrape issue: 4133.67 minutes
# 49604
# Issue added! Time needed to scrape issue: 4142.25 minutes
# 49707
# Issue added! Time needed to scrape issue: 4150.92 minutes
# 49811
# Issue added! Time needed to scrape issue: 4159.42 minutes
# 49913
# Issue added! Time needed to scrape issue: 4167.92 minutes
# 50015
# Issue added! Time needed to scrape issue: 4176.42 minutes
# 50117
# Issue added! Time needed to scrape issue: 4184.92 minutes
# 50219
# Issue added! Time needed to scrape issue: 4193.25 minutes
# 50319
# Issue added! Time needed to scrape issue: 4202.33 minutes
# 50428
# Issue added! Time needed to scrape issue: 4210.75 minutes
# 50529
# Issue added! Time needed to scrape issue: 4219.25 minutes
# 50631
# Issue added! Time needed to scrape issue: 4228.08 minutes
# 50737
# Issue added! Time needed to scrape issue: 4236.67 minutes
# 50840
# Issue added! Time needed to scrape issue: 4244.5 minutes
# 50934
# Issue added! Time needed to scrape issue: 4252.58 minutes
# 51031
# Issue added! Time needed to scrape issue: 4260.58 minutes
# 51127
# Issue added! Time needed to scrape issue: 4268.92 minutes
# 51227
# Issue added! Time needed to scrape issue: 4277.42 minutes
# 51329
# Issue added! Time needed to scrape issue: 4285.58 minutes
# 51427
# Issue added! Time needed to scrape issue: 4293.75 minutes
# 51525
# Issue added! Time needed to scrape issue: 4302.0 minutes
# 51624
# Issue added! Time needed to scrape issue: 4310.33 minutes
# 51724
# Issue added! Time needed to scrape issue: 4318.75 minutes
# 51825
# Issue added! Time needed to scrape issue: 4327.58 minutes
# 51931
# Issue added! Time needed to scrape issue: 4336.08 minutes
# 52033
# Issue added! Time needed to scrape issue: 4344.67 minutes
# 52136
# Issue added! Time needed to scrape issue: 4352.67 minutes
# 52232
# Issue added! Time needed to scrape issue: 4360.5 minutes
# 52326
# Issue added! Time needed to scrape issue: 4368.92 minutes
# 52427
# Issue added! Time needed to scrape issue: 4377.08 minutes
# 52525
# Issue added! Time needed to scrape issue: 4385.33 minutes
# 52624
# Issue added! Time needed to scrape issue: 4393.5 minutes
# 52722
# Issue added! Time needed to scrape issue: 4401.92 minutes
# 52823
# Issue added! Time needed to scrape issue: 4410.08 minutes
# 52921
# Issue added! Time needed to scrape issue: 4417.75 minutes
# 53013
# Issue added! Time needed to scrape issue: 4425.83 minutes
# 53110
# Issue added! Time needed to scrape issue: 4434.67 minutes
# 53216
# Issue added! Time needed to scrape issue: 4442.92 minutes
# 53315
# Issue added! Time needed to scrape issue: 4451.08 minutes
# 53413
# Issue added! Time needed to scrape issue: 4459.5 minutes
# 53514
# Issue added! Time needed to scrape issue: 4467.92 minutes
# 53615
# Issue added! Time needed to scrape issue: 4476.5 minutes
# 53718
# Issue added! Time needed to scrape issue: 4484.0 minutes
# 53808
# Issue added! Time needed to scrape issue: 4492.17 minutes
# 53906
# Issue added! Time needed to scrape issue: 4500.0 minutes
# 54000
# Issue added! Time needed to scrape issue: 4508.25 minutes
# 54099
# Issue added! Time needed to scrape issue: 4516.0 minutes
# 54192
# Issue added! Time needed to scrape issue: 4523.83 minutes
# 54286
# Issue added! Time needed to scrape issue: 4531.67 minutes
# 54380
# Issue added! Time needed to scrape issue: 4539.67 minutes
# 54476
# Issue added! Time needed to scrape issue: 4547.33 minutes
# 54568
# Issue added! Time needed to scrape issue: 4556.0 minutes
# 54672
# Issue added! Time needed to scrape issue: 4564.42 minutes
# 54773
# Issue added! Time needed to scrape issue: 4572.67 minutes
# 54872
# Issue added! Time needed to scrape issue: 4580.75 minutes
# 54969
# Issue added! Time needed to scrape issue: 4589.83 minutes
# 55078
# Issue added! Time needed to scrape issue: 4598.58 minutes
# 55183
# Issue added! Time needed to scrape issue: 4607.33 minutes
# 55288
# Issue added! Time needed to scrape issue: 4615.42 minutes
# 55385
# Issue added! Time needed to scrape issue: 4624.5 minutes
# 55494
# Issue added! Time needed to scrape issue: 4632.5 minutes
# 55590
# Issue added! Time needed to scrape issue: 4640.83 minutes
# 55690
# Issue added! Time needed to scrape issue: 4649.5 minutes
# 55794
# Issue added! Time needed to scrape issue: 4658.08 minutes
# 55897
# Issue added! Time needed to scrape issue: 4666.58 minutes
# 55999
# Issue added! Time needed to scrape issue: 4674.83 minutes
# 56098
# Issue added! Time needed to scrape issue: 4683.0 minutes
# 56196
# Issue added! Time needed to scrape issue: 4690.83 minutes
# 56290
# Issue added! Time needed to scrape issue: 4698.92 minutes
# 56387
# Issue added! Time needed to scrape issue: 4707.25 minutes
# 56487
# Issue added! Time needed to scrape issue: 4715.42 minutes
# 56585
# Issue added! Time needed to scrape issue: 4723.08 minutes
# 56677
# Issue added! Time needed to scrape issue: 4731.92 minutes
# 56783
# Issue added! Time needed to scrape issue: 4740.42 minutes
# 56885
# Issue added! Time needed to scrape issue: 4748.58 minutes
# 56983
# Issue added! Time needed to scrape issue: 4756.92 minutes
# 57083
# Issue added! Time needed to scrape issue: 4765.17 minutes
# 57182
# Issue added! Time needed to scrape issue: 4773.75 minutes
# 57285
# Issue added! Time needed to scrape issue: 4781.33 minutes
# 57376
# Issue added! Time needed to scrape issue: 4789.92 minutes
# 57479
# Issue added! Time needed to scrape issue: 4798.5 minutes
# 57582
# Issue added! Time needed to scrape issue: 4806.5 minutes
# 57678
# Issue added! Time needed to scrape issue: 4814.83 minutes
# 57778
# Issue added! Time needed to scrape issue: 4823.58 minutes
# 57883
# Issue added! Time needed to scrape issue: 4831.17 minutes
# 57974
# Issue added! Time needed to scrape issue: 4839.33 minutes
# 58072
# Issue added! Time needed to scrape issue: 4847.83 minutes
# 58174
# Issue added! Time needed to scrape issue: 4856.25 minutes
# 58275
# Issue added! Time needed to scrape issue: 4863.75 minutes
# 58365
# Issue added! Time needed to scrape issue: 4872.08 minutes
# 58465
# Issue added! Time needed to scrape issue: 4880.25 minutes
# 58563
# Issue added! Time needed to scrape issue: 4888.25 minutes
# 58659
# Issue added! Time needed to scrape issue: 4896.42 minutes
# 58757
# Issue added! Time needed to scrape issue: 4903.83 minutes
# 58846
# Issue added! Time needed to scrape issue: 4911.58 minutes
# 58939
# Issue added! Time needed to scrape issue: 4919.42 minutes
# 59033
# Issue added! Time needed to scrape issue: 4927.5 minutes
# 59130
# Issue added! Time needed to scrape issue: 4935.42 minutes
# 59225
# Issue added! Time needed to scrape issue: 4942.92 minutes
# 59315
# Issue added! Time needed to scrape issue: 4950.92 minutes
# 59411
# Issue added! Time needed to scrape issue: 4959.08 minutes
# 59509
# Issue added! Time needed to scrape issue: 4966.92 minutes
# 59603
# Issue added! Time needed to scrape issue: 4974.92 minutes
# 59699
# Issue added! Time needed to scrape issue: 4982.67 minutes
# 59792
# Issue added! Time needed to scrape issue: 4990.5 minutes
# 59886
# Issue added! Time needed to scrape issue: 4998.42 minutes
# 59981
# Issue added! Time needed to scrape issue: 5006.17 minutes
# 60074
# Issue added! Time needed to scrape issue: 5014.58 minutes
# 60175
# Issue added! Time needed to scrape issue: 5022.92 minutes
# 60275
# Issue added! Time needed to scrape issue: 5031.33 minutes
# 60376
# Issue added! Time needed to scrape issue: 5039.17 minutes
# 60470
# Issue added! Time needed to scrape issue: 5048.0 minutes
# 60576
# Issue added! Time needed to scrape issue: 5056.17 minutes
# 60674
# Issue added! Time needed to scrape issue: 5064.08 minutes
# 60769
# Issue added! Time needed to scrape issue: 5071.67 minutes
# 60860
# Issue added! Time needed to scrape issue: 5080.25 minutes
# 60963
# Issue added! Time needed to scrape issue: 5088.17 minutes
# 61058
# Issue added! Time needed to scrape issue: 5096.33 minutes
# 61156
# Issue added! Time needed to scrape issue: 5104.33 minutes
# 61252
# Issue added! Time needed to scrape issue: 5112.83 minutes
# 61354
# Issue added! Time needed to scrape issue: 5120.92 minutes
# 61451
# Issue added! Time needed to scrape issue: 5128.92 minutes
# 61547
# Issue added! Time needed to scrape issue: 5137.17 minutes
# 61646
# Issue added! Time needed to scrape issue: 5145.92 minutes
# 61751
# Issue added! Time needed to scrape issue: 5153.33 minutes
# 61840
# Issue added! Time needed to scrape issue: 5161.5 minutes
# 61938
# Issue added! Time needed to scrape issue: 5169.17 minutes
# 62030
# Issue added! Time needed to scrape issue: 5176.67 minutes
# 62120
# Issue added! Time needed to scrape issue: 5183.67 minutes
# 62204
# Issue added! Time needed to scrape issue: 5191.33 minutes
# 62296
# Issue added! Time needed to scrape issue: 5198.42 minutes
# 62381
# Issue added! Time needed to scrape issue: 5206.33 minutes
# 62476
# Issue added! Time needed to scrape issue: 5213.67 minutes
# 62564
# Issue added! Time needed to scrape issue: 5221.0 minutes
# 62652
# Issue added! Time needed to scrape issue: 5229.0 minutes
# 62748
# Issue added! Time needed to scrape issue: 5235.83 minutes
# 62830
# Issue added! Time needed to scrape issue: 5242.42 minutes
# 62909
# Issue added! Time needed to scrape issue: 5250.42 minutes
# 63005
# Issue added! Time needed to scrape issue: 5258.0 minutes
# 63096
# Issue added! Time needed to scrape issue: 5265.75 minutes
# 63189
# Issue added! Time needed to scrape issue: 5273.5 minutes
# 63282
# Issue added! Time needed to scrape issue: 5280.67 minutes
# 63368
# Issue added! Time needed to scrape issue: 5288.83 minutes
# 63466
# Issue added! Time needed to scrape issue: 5295.83 minutes
# 63550
# Issue added! Time needed to scrape issue: 5303.42 minutes
# 63641
# Issue added! Time needed to scrape issue: 5311.0 minutes
# 63732
# Issue added! Time needed to scrape issue: 5318.5 minutes
# 63822
# Issue added! Time needed to scrape issue: 5325.67 minutes
# 63908
# Issue added! Time needed to scrape issue: 5333.33 minutes
# 64000
# Issue added! Time needed to scrape issue: 5341.08 minutes
# 64093
# Issue added! Time needed to scrape issue: 5348.75 minutes
# 64185
# Issue added! Time needed to scrape issue: 5356.42 minutes
# 64277
# Issue added! Time needed to scrape issue: 5364.58 minutes
# 64375
# Issue added! Time needed to scrape issue: 5371.92 minutes
# 64463
# Issue added! Time needed to scrape issue: 5379.58 minutes
# 64555
# Issue added! Time needed to scrape issue: 5386.92 minutes
# 64643
# Issue added! Time needed to scrape issue: 5393.83 minutes
# 64726
# Issue added! Time needed to scrape issue: 5401.17 minutes
# 64814
# Issue added! Time needed to scrape issue: 5408.5 minutes
# 64902
# Issue added! Time needed to scrape issue: 5416.0 minutes
# 64992
# Issue added! Time needed to scrape issue: 5423.25 minutes
# 65079
# Issue added! Time needed to scrape issue: 5430.67 minutes
# 65168
# Issue added! Time needed to scrape issue: 5438.25 minutes
# 65259
# Issue added! Time needed to scrape issue: 5445.42 minutes
# 65345
# Issue added! Time needed to scrape issue: 5452.92 minutes
# 65435
# Issue added! Time needed to scrape issue: 5460.42 minutes
# 65525
# Issue added! Time needed to scrape issue: 5467.75 minutes
# 65613
# Issue added! Time needed to scrape issue: 5475.33 minutes
# 65704
# Issue added! Time needed to scrape issue: 5482.67 minutes
# 65792
# Issue added! Time needed to scrape issue: 5490.08 minutes
# 65881
# Issue added! Time needed to scrape issue: 5497.83 minutes
# 65974
# Issue added! Time needed to scrape issue: 5505.33 minutes
# 66064
# Issue added! Time needed to scrape issue: 5512.92 minutes
# 66155
# Issue added! Time needed to scrape issue: 5519.83 minutes
# 66238
# Issue added! Time needed to scrape issue: 5527.42 minutes
# 66329
# Issue added! Time needed to scrape issue: 5534.75 minutes
# 66417
# Issue added! Time needed to scrape issue: 5542.08 minutes
# 66505
# Issue added! Time needed to scrape issue: 5549.83 minutes
# 66598
# Issue added! Time needed to scrape issue: 5556.92 minutes
# 66683
# Issue added! Time needed to scrape issue: 5564.33 minutes
# 66772
# Issue added! Time needed to scrape issue: 5572.0 minutes
# 66864
# Issue added! Time needed to scrape issue: 5579.58 minutes
# 66955
# Issue added! Time needed to scrape issue: 5586.92 minutes
# 67043
# Issue added! Time needed to scrape issue: 5594.42 minutes
# 67133
# Issue added! Time needed to scrape issue: 5601.58 minutes
# 67219
# Issue added! Time needed to scrape issue: 5609.08 minutes
# 67309
# Issue added! Time needed to scrape issue: 5615.75 minutes
# 67389
# Issue added! Time needed to scrape issue: 5623.08 minutes
# 67477
# Issue added! Time needed to scrape issue: 5631.0 minutes
# 67572
# Issue added! Time needed to scrape issue: 5638.67 minutes
# 67664
# Issue added! Time needed to scrape issue: 5646.67 minutes
# 67760
# Issue added! Time needed to scrape issue: 5654.33 minutes
# 67852
# Issue added! Time needed to scrape issue: 5661.92 minutes
# 67943
# Issue added! Time needed to scrape issue: 5669.5 minutes
# 68034
# Issue added! Time needed to scrape issue: 5677.08 minutes
# 68125
# Issue added! Time needed to scrape issue: 5684.42 minutes
# 68213
# Issue added! Time needed to scrape issue: 5692.17 minutes
# 68306
# Issue added! Time needed to scrape issue: 5700.0 minutes
# 68400
# Issue added! Time needed to scrape issue: 5708.0 minutes
# 68496
# Issue added! Time needed to scrape issue: 5715.67 minutes
# 68588
# Issue added! Time needed to scrape issue: 5722.67 minutes
# 68672
# Issue added! Time needed to scrape issue: 5730.17 minutes
# 68762
# Issue added! Time needed to scrape issue: 5737.83 minutes
# 68854
# Issue added! Time needed to scrape issue: 5745.17 minutes
# 68942
# Issue added! Time needed to scrape issue: 5752.83 minutes
# 69034
# Issue added! Time needed to scrape issue: 5760.42 minutes
# 69125
# Issue added! Time needed to scrape issue: 5768.17 minutes
# 69218
# Issue added! Time needed to scrape issue: 5775.17 minutes
# 69302
# Issue added! Time needed to scrape issue: 5782.83 minutes
# 69394
# Issue added! Time needed to scrape issue: 5790.17 minutes
# 69482
# Issue added! Time needed to scrape issue: 5797.75 minutes
# 69573
# Issue added! Time needed to scrape issue: 5805.5 minutes
# 69666
# Issue added! Time needed to scrape issue: 5812.92 minutes
# 69755
# Issue added! Time needed to scrape issue: 5820.5 minutes
# 69846
# Issue added! Time needed to scrape issue: 5828.17 minutes
# 69938
# Issue added! Time needed to scrape issue: 5835.58 minutes
# 70027
# Issue added! Time needed to scrape issue: 5843.17 minutes
# 70118
# Issue added! Time needed to scrape issue: 5851.17 minutes
# 70214
# Issue added! Time needed to scrape issue: 5859.33 minutes
# 70312
# Issue added! Time needed to scrape issue: 5866.42 minutes
# 70397
# Issue added! Time needed to scrape issue: 5873.92 minutes
# 70487
# Issue added! Time needed to scrape issue: 5881.08 minutes
# 70573
# Issue added! Time needed to scrape issue: 5888.42 minutes
# 70661
# Issue added! Time needed to scrape issue: 5895.58 minutes
# 70747
# Issue added! Time needed to scrape issue: 5902.83 minutes
# 70834
# Issue added! Time needed to scrape issue: 5910.75 minutes
# 70929
# Issue added! Time needed to scrape issue: 5918.17 minutes
# 71018
# Issue added! Time needed to scrape issue: 5925.92 minutes
# 71111
# Issue added! Time needed to scrape issue: 5933.42 minutes
# 71201
# Issue added! Time needed to scrape issue: 5940.92 minutes
# 71291
# Issue added! Time needed to scrape issue: 5948.83 minutes
# 71386
# Issue added! Time needed to scrape issue: 5956.33 minutes
# 71476
# Issue added! Time needed to scrape issue: 5963.5 minutes
# 71562
# Issue added! Time needed to scrape issue: 5971.33 minutes
# 71656
# Issue added! Time needed to scrape issue: 5979.08 minutes
# 71749
# Issue added! Time needed to scrape issue: 5986.75 minutes
# 71841
# Issue added! Time needed to scrape issue: 5994.17 minutes
# 71930
# Issue added! Time needed to scrape issue: 6000.83 minutes
# 72010
# Issue added! Time needed to scrape issue: 6008.0 minutes
# 72096
# Issue added! Time needed to scrape issue: 6015.33 minutes
# 72184
# Issue added! Time needed to scrape issue: 6022.5 minutes
# 72270
# Issue added! Time needed to scrape issue: 6029.83 minutes
# 72358
# Issue added! Time needed to scrape issue: 6037.5 minutes
# 72450
# Issue added! Time needed to scrape issue: 6045.08 minutes
# 72541
# Issue added! Time needed to scrape issue: 6052.42 minutes
# 72629
# Issue added! Time needed to scrape issue: 6059.92 minutes
# 72719
# Issue added! Time needed to scrape issue: 6067.33 minutes
# 72808
# Issue added! Time needed to scrape issue: 6074.83 minutes
# 72898
# Issue added! Time needed to scrape issue: 6082.17 minutes
# 72986
# Issue added! Time needed to scrape issue: 6089.58 minutes
# 73075
# Issue added! Time needed to scrape issue: 6097.08 minutes
# 73165
# Issue added! Time needed to scrape issue: 6104.58 minutes
# 73255
# Issue added! Time needed to scrape issue: 6112.17 minutes
# 73346
# Issue added! Time needed to scrape issue: 6119.83 minutes
# 73438
# Issue added! Time needed to scrape issue: 6127.33 minutes
# 73528
# Issue added! Time needed to scrape issue: 6134.58 minutes
# 73615
# Issue added! Time needed to scrape issue: 6141.5 minutes
# 73698
# Issue added! Time needed to scrape issue: 6149.0 minutes
# 73788
# Issue added! Time needed to scrape issue: 6156.75 minutes
# 73881
# Issue added! Time needed to scrape issue: 6164.42 minutes
# 73973
# Issue added! Time needed to scrape issue: 6172.17 minutes
# 74066
# Issue added! Time needed to scrape issue: 6179.75 minutes
# 74157
# Issue added! Time needed to scrape issue: 6187.67 minutes
# 74252
# Issue added! Time needed to scrape issue: 6195.0 minutes
# 74340
# Issue added! Time needed to scrape issue: 6202.5 minutes
# 74430
# Issue added! Time needed to scrape issue: 6210.08 minutes
# 74521
# Issue added! Time needed to scrape issue: 6217.58 minutes
# 74611
# Issue added! Time needed to scrape issue: 6224.5 minutes
# 74694
# Issue added! Time needed to scrape issue: 6232.5 minutes
# 74790
# Issue added! Time needed to scrape issue: 6240.33 minutes
# 74884
# Issue added! Time needed to scrape issue: 6247.67 minutes
# 74972
# Issue added! Time needed to scrape issue: 6255.33 minutes
# 75064
# Issue added! Time needed to scrape issue: 6262.83 minutes
# 75154
# Issue added! Time needed to scrape issue: 6270.42 minutes
# 75245
# Issue added! Time needed to scrape issue: 6278.25 minutes
# 75339
# Issue added! Time needed to scrape issue: 6285.67 minutes
# 75428
# Issue added! Time needed to scrape issue: 6293.0 minutes
# 75516
# Issue added! Time needed to scrape issue: 6300.25 minutes
# 75603
# Issue added! Time needed to scrape issue: 6307.25 minutes
# 75687
# Issue added! Time needed to scrape issue: 6314.5 minutes
# 75774
# Issue added! Time needed to scrape issue: 6322.17 minutes
# 75866
# Issue added! Time needed to scrape issue: 6329.58 minutes
# 75955
# Issue added! Time needed to scrape issue: 6336.58 minutes
# 76039
# Issue added! Time needed to scrape issue: 6344.17 minutes
# 76130
# Issue added! Time needed to scrape issue: 6351.83 minutes
# 76222
# Issue added! Time needed to scrape issue: 6359.42 minutes
# 76313
# Issue added! Time needed to scrape issue: 6366.92 minutes
# 76403
# Issue added! Time needed to scrape issue: 6374.33 minutes
# 76492
# Issue added! Time needed to scrape issue: 6381.58 minutes
# 76579
# Issue added! Time needed to scrape issue: 6388.92 minutes
# 76667
# Issue added! Time needed to scrape issue: 6396.75 minutes
# 76761
# Issue added! Time needed to scrape issue: 6404.25 minutes
# 76851
# Issue added! Time needed to scrape issue: 6411.58 minutes
# 76939
# Issue added! Time needed to scrape issue: 6419.58 minutes
# 77035
# Issue added! Time needed to scrape issue: 6426.92 minutes
# 77123
# Issue added! Time needed to scrape issue: 6434.5 minutes
# 77214
# Issue added! Time needed to scrape issue: 6441.33 minutes
# 77296
# Issue added! Time needed to scrape issue: 6447.83 minutes
# 77374
# Issue added! Time needed to scrape issue: 6455.42 minutes
# 77465
# Issue added! Time needed to scrape issue: 6462.75 minutes
# 77553
# Issue added! Time needed to scrape issue: 6470.42 minutes
# 77645
# Issue added! Time needed to scrape issue: 6477.58 minutes
# 77731
# Issue added! Time needed to scrape issue: 6484.83 minutes
# 77818
# Issue added! Time needed to scrape issue: 6491.33 minutes
# 77896
# Issue added! Time needed to scrape issue: 6498.58 minutes
# 77983
# Issue added! Time needed to scrape issue: 6506.5 minutes
# 78078
# Issue added! Time needed to scrape issue: 6511.58 minutes
# 78139
# Issue added! Time needed to scrape issue: 6517.0 minutes
# 78204
# Issue added! Time needed to scrape issue: 6522.75 minutes
# 78273
# Issue added! Time needed to scrape issue: 6527.67 minutes
# 78332
# Issue added! Time needed to scrape issue: 6532.83 minutes
# 78394
# Issue added! Time needed to scrape issue: 6538.33 minutes
# 78460
# Issue added! Time needed to scrape issue: 6543.33 minutes
# 78520
# Issue added! Time needed to scrape issue: 6548.83 minutes
# 78586
# Issue added! Time needed to scrape issue: 6554.08 minutes
# 78649
# Issue added! Time needed to scrape issue: 6559.08 minutes
# 78709
# Issue added! Time needed to scrape issue: 6564.0 minutes
# 78768
# Issue added! Time needed to scrape issue: 6569.17 minutes
# 78830
# Issue added! Time needed to scrape issue: 6574.83 minutes
# 78898
# Issue added! Time needed to scrape issue: 6580.25 minutes
# 78963
# Issue added! Time needed to scrape issue: 6585.5 minutes
# 79026
# Issue added! Time needed to scrape issue: 6590.83 minutes
# 79090
# Issue added! Time needed to scrape issue: 6596.0 minutes
# 79152
# Issue added! Time needed to scrape issue: 6601.33 minutes
# 79216
# Issue added! Time needed to scrape issue: 6606.58 minutes
# 79279
# Issue added! Time needed to scrape issue: 6611.75 minutes
# 79341
# Issue added! Time needed to scrape issue: 6616.83 minutes
# 79402
# Issue added! Time needed to scrape issue: 6622.33 minutes
# 79468
# Issue added! Time needed to scrape issue: 6627.67 minutes
# ...
# 87466
# Issue added! Time needed to scrape issue: 7294.0 minutes
# 87528
# Issue added! Time needed to scrape issue: 7298.92 minutes
# 87587
# Issue added! Time needed to scrape issue: 7307.08 minutes
# 87685
# Issue added! Time needed to scrape issue: 7312.0 minutes
# 87744
# Issue added! Time needed to scrape issue: 7317.42 minutes
# 87809
# Issue added! Time needed to scrape issue: 7325.17 minutes
# 87902
# Issue added! Time needed to scrape issue: 7330.58 minutes
# 87967
# Issue added! Time needed to scrape issue: 7335.83 minutes
# 88030
# Issue added! Time needed to scrape issue: 7341.08 minutes
# 88093
# Issue added! Time needed to scrape issue: 7346.92 minutes
# 88163
# Issue added! Time needed to scrape issue: 7352.5 minutes
# 88230
# Issue added! Time needed to scrape issue: 7360.75 minutes
# 88329
# Issue added! Time needed to scrape issue: 7366.08 minutes
# 88393
# Issue added! Time needed to scrape issue: 7372.0 minutes
# 88464
# Issue added! Time needed to scrape issue: 7377.25 minutes
# 88527
# Issue added! Time needed to scrape issue: 7382.75 minutes
# 88593
# Issue added! Time needed to scrape issue: 7387.42 minutes
# 88649
# Issue added! Time needed to scrape issue: 7392.58 minutes
# 88711
# Issue added! Time needed to scrape issue: 7400.17 minutes
# 88802
# Issue added! Time needed to scrape issue: 7405.42 minutes
# 88865
# Issue added! Time needed to scrape issue: 7410.33 minutes
# 88924
# Issue added! Time needed to scrape issue: 7415.42 minutes
# 88985
# Issue added! Time needed to scrape issue: 7420.5 minutes
# 89046
# Issue added! Time needed to scrape issue: 7425.92 minutes
# 89111
# Issue added! Time needed to scrape issue: 7432.42 minutes
# 89189
# Issue added! Time needed to scrape issue: 7437.33 minutes
# 89248
# Issue added! Time needed to scrape issue: 7442.5 minutes
# 89310
# Issue added! Time needed to scrape issue: 7447.25 minutes
# 89367
# Issue added! Time needed to scrape issue: 7454.33 minutes
# 89452
# Issue added! Time needed to scrape issue: 7459.67 minutes
# 89516
# Issue added! Time needed to scrape issue: 7465.0 minutes
# 89580
# Issue added! Time needed to scrape issue: 7470.0 minutes
# 89640
# Issue added! Time needed to scrape issue: 7476.5 minutes
# 89718
# Issue added! Time needed to scrape issue: 7483.5 minutes
# 89802
# Issue added! Time needed to scrape issue: 7489.25 minutes
# 89871
# Issue added! Time needed to scrape issue: 7494.75 minutes
# 89937
# Issue added! Time needed to scrape issue: 7500.08 minutes
# 90001
# Issue added! Time needed to scrape issue: 7507.42 minutes
# 90089
# Issue added! Time needed to scrape issue: 7512.25 minutes
# 90147
# Issue added! Time needed to scrape issue: 7517.58 minutes
# 90211
# Issue added! Time needed to scrape issue: 7522.75 minutes
# 90273
# Issue added! Time needed to scrape issue: 7530.17 minutes
# 90362
# Issue added! Time needed to scrape issue: 7534.83 minutes
# 90418
# Issue added! Time needed to scrape issue: 7540.33 minutes
# 90484
# Issue added! Time needed to scrape issue: 7545.25 minutes
# 90543
# Issue added! Time needed to scrape issue: 7550.92 minutes
# 90611
# Issue added! Time needed to scrape issue: 7555.67 minutes
# 90668
# Issue added! Time needed to scrape issue: 7561.08 minutes
# 90733
# Issue added! Time needed to scrape issue: 7566.17 minutes
# 90794
# Issue added! Time needed to scrape issue: 7573.42 minutes
# 90881
# Issue added! Time needed to scrape issue: 7578.75 minutes
# 90945
# Issue added! Time needed to scrape issue: 7584.0 minutes
# 91008
# Issue added! Time needed to scrape issue: 7589.5 minutes
# 91074
# Issue added! Time needed to scrape issue: 7594.58 minutes
# 91135
# Issue added! Time needed to scrape issue: 7602.33 minutes
# 91228
# Issue added! Time needed to scrape issue: 7609.25 minutes
# 91311
# Issue added! Time needed to scrape issue: 7614.33 minutes
# 91372
# Issue added! Time needed to scrape issue: 7619.25 minutes
# 91431
# Issue added! Time needed to scrape issue: 7626.08 minutes
# 91513
# Issue added! Time needed to scrape issue: 7630.75 minutes
# 91569
# Issue added! Time needed to scrape issue: 7635.67 minutes
# 91628
# Issue added! Time needed to scrape issue: 7640.83 minutes
# 91690
# Issue added! Time needed to scrape issue: 7647.92 minutes
# 91775
# Issue added! Time needed to scrape issue: 7652.5 minutes
# 91830
# Issue added! Time needed to scrape issue: 7657.42 minutes
# 91889
# Issue added! Time needed to scrape issue: 7664.42 minutes
# 91973
# Issue added! Time needed to scrape issue: 7669.67 minutes
# 92036
# Issue added! Time needed to scrape issue: 7674.83 minutes
# 92098
# Issue added! Time needed to scrape issue: 7679.92 minutes
# 92159
# Issue added! Time needed to scrape issue: 7687.5 minutes
# 92250
# Issue added! Time needed to scrape issue: 7692.67 minutes
# 92312
# Issue added! Time needed to scrape issue: 7698.08 minutes
# 92377
# Issue added! Time needed to scrape issue: 7703.33 minutes
# 92440
# Issue added! Time needed to scrape issue: 7708.42 minutes
# 92501
# Issue added! Time needed to scrape issue: 7713.92 minutes
# 92567
# Issue added! Time needed to scrape issue: 7719.42 minutes
# 92633
# Issue added! Time needed to scrape issue: 7724.67 minutes
# 92696
# Issue added! Time needed to scrape issue: 7729.75 minutes
# 92757
# Issue added! Time needed to scrape issue: 7735.17 minutes
# 92822
# Issue added! Time needed to scrape issue: 7742.0 minutes
# 92904
# Issue added! Time needed to scrape issue: 7746.83 minutes
# 92962
# Issue added! Time needed to scrape issue: 7751.92 minutes
# 93023
# Issue added! Time needed to scrape issue: 7757.75 minutes
# 93093
# Issue added! Time needed to scrape issue: 7762.75 minutes
# 93153
# Issue added! Time needed to scrape issue: 7772.08 minutes
# 93265
# Issue added! Time needed to scrape issue: 7778.92 minutes
# 93347
# Issue added! Time needed to scrape issue: 7784.42 minutes
# 93413
# Issue added! Time needed to scrape issue: 7789.83 minutes
# 93478
# Issue added! Time needed to scrape issue: 7796.92 minutes
# 93563
# Issue added! Time needed to scrape issue: 7801.83 minutes
# 93622
# Issue added! Time needed to scrape issue: 7807.08 minutes
# 93685
# Issue added! Time needed to scrape issue: 7813.92 minutes
# 93767
# Issue added! Time needed to scrape issue: 7822.17 minutes
# 93866
# Issue added! Time needed to scrape issue: 7826.67 minutes
# 93920
# Issue added! Time needed to scrape issue: 7832.0 minutes
# 93984
# Issue added! Time needed to scrape issue: 7837.33 minutes
# 94048
# Issue added! Time needed to scrape issue: 7842.17 minutes
# 94106
# Issue added! Time needed to scrape issue: 7847.33 minutes
# 94168
# Issue added! Time needed to scrape issue: 7852.42 minutes
# 94229
# Issue added! Time needed to scrape issue: 7857.67 minutes
# 94292
# Issue added! Time needed to scrape issue: 7862.67 minutes
# 94352
# Issue added! Time needed to scrape issue: 7867.58 minutes
# 94411
# Issue added! Time needed to scrape issue: 7873.08 minutes
# 94477
# Issue added! Time needed to scrape issue: 7878.58 minutes
# 94543
# Issue added! Time needed to scrape issue: 7883.83 minutes
# 94606
# Issue added! Time needed to scrape issue: 7889.0 minutes
# 94668
# Issue added! Time needed to scrape issue: 7894.75 minutes
# 94737
# Issue added! Time needed to scrape issue: 7902.17 minutes
# 94826
# Issue added! Time needed to scrape issue: 7909.83 minutes
# 94918
# Issue added! Time needed to scrape issue: 7915.33 minutes
# 94984
# Issue added! Time needed to scrape issue: 7920.83 minutes
# 95050
# Issue added! Time needed to scrape issue: 7926.08 minutes
# 95113
# Issue added! Time needed to scrape issue: 7931.08 minutes
# 95173
# Issue added! Time needed to scrape issue: 7936.08 minutes
# 95233
# Issue added! Time needed to scrape issue: 7941.25 minutes
# 95295
# Issue added! Time needed to scrape issue: 7946.5 minutes
# 95358
# Issue added! Time needed to scrape issue: 7953.25 minutes
# 95439
# Issue added! Time needed to scrape issue: 7958.5 minutes
# 95502
# Issue added! Time needed to scrape issue: 7963.58 minutes
# 95563
# Issue added! Time needed to scrape issue: 7969.08 minutes
# 95629
# Issue added! Time needed to scrape issue: 7976.5 minutes
# 95718
# Issue added! Time needed to scrape issue: 7981.5 minutes
# 95778
# Issue added! Time needed to scrape issue: 7987.17 minutes
# 95846
# Issue added! Time needed to scrape issue: 7992.67 minutes
# 95912
# Issue added! Time needed to scrape issue: 7997.83 minutes
# 95974
# Issue added! Time needed to scrape issue: 8002.92 minutes
# 96035
# Issue added! Time needed to scrape issue: 8008.5 minutes
# 96102
# Issue added! Time needed to scrape issue: 8013.42 minutes
# 96161
# Issue added! Time needed to scrape issue: 8018.5 minutes
# 96222
# Issue added! Time needed to scrape issue: 8023.83 minutes
# 96286
# Issue added! Time needed to scrape issue: 8029.33 minutes
# 96352
# Issue added! Time needed to scrape issue: 8034.92 minutes
# 96419
# Issue added! Time needed to scrape issue: 8040.25 minutes
# 96483
# Issue added! Time needed to scrape issue: 8046.17 minutes
# 96554
# Issue added! Time needed to scrape issue: 8051.58 minutes
# 96619
# Issue added! Time needed to scrape issue: 8056.92 minutes
# 96683
# Issue added! Time needed to scrape issue: 8064.33 minutes
# 96772
# Issue added! Time needed to scrape issue: 8069.33 minutes
# 96832
# Issue added! Time needed to scrape issue: 8075.17 minutes
# 96902
# Issue added! Time needed to scrape issue: 8080.83 minutes
# 96970
# Issue added! Time needed to scrape issue: 8086.25 minutes
# 97035
# Issue added! Time needed to scrape issue: 8091.17 minutes
# 97094
# Issue added! Time needed to scrape issue: 8096.17 minutes
# 97154
# Issue added! Time needed to scrape issue: 8101.08 minutes
# 97213
# Issue added! Time needed to scrape issue: 8108.92 minutes
# 97307
# Issue added! Time needed to scrape issue: 8114.0 minutes
# 97368
# Issue added! Time needed to scrape issue: 8118.58 minutes
# 97423
# Issue added! Time needed to scrape issue: 8122.5 minutes
# 97470
# Issue added! Time needed to scrape issue: 8127.92 minutes
# 97535
# Issue added! Time needed to scrape issue: 8133.33 minutes
# 97600
# Issue added! Time needed to scrape issue: 8138.67 minutes
# 97664
# Issue added! Time needed to scrape issue: 8144.58 minutes
# 97735
# Issue added! Time needed to scrape issue: 8150.25 minutes
# 97803
# Issue added! Time needed to scrape issue: 8155.58 minutes
# 97867
# Issue added! Time needed to scrape issue: 8161.5 minutes
# 97938
# Issue added! Time needed to scrape issue: 8167.33 minutes
# 98008
# Issue added! Time needed to scrape issue: 8173.0 minutes
# 98076
# Issue added! Time needed to scrape issue: 8178.33 minutes
# 98140
# Issue added! Time needed to scrape issue: 8183.83 minutes
# 98206
# Issue added! Time needed to scrape issue: 8188.17 minutes
# 98258
# Issue added! Time needed to scrape issue: 8194.92 minutes
# 98339
# Issue added! Time needed to scrape issue: 8200.58 minutes
# 98407
# Issue added! Time needed to scrape issue: 8206.33 minutes
# 98476
# Issue added! Time needed to scrape issue: 8212.08 minutes
# 98545
# Issue added! Time needed to scrape issue: 8218.0 minutes
# 98616
# Issue added! Time needed to scrape issue: 8223.5 minutes
# 98682
# Issue added! Time needed to scrape issue: 8229.58 minutes
# 98755
# Issue added! Time needed to scrape issue: 8236.0 minutes
# 98832
# Issue added! Time needed to scrape issue: 8241.17 minutes
# 98894
# Issue added! Time needed to scrape issue: 8246.5 minutes
# 98958
# Issue added! Time needed to scrape issue: 8252.08 minutes
# 99025
# Issue added! Time needed to scrape issue: 8257.58 minutes
# 99091
# Issue added! Time needed to scrape issue: 8264.92 minutes
# 99179
# Issue added! Time needed to scrape issue: 8270.17 minutes
# 99242
# Issue added! Time needed to scrape issue: 8275.83 minutes
# 99310
# Issue added! Time needed to scrape issue: 8281.0 minutes
# 99372
# Issue added! Time needed to scrape issue: 8286.25 minutes
# 99435
# Issue added! Time needed to scrape issue: 8291.42 minutes
# 99497
# Issue added! Time needed to scrape issue: 8296.58 minutes
# 99559
# Issue added! Time needed to scrape issue: 8302.5 minutes
# 99630
# Issue added! Time needed to scrape issue: 8307.5 minutes
# 99690
# Issue added! Time needed to scrape issue: 8313.0 minutes
# 99756
# Issue added! Time needed to scrape issue: 8318.67 minutes
# 99824
# Issue added! Time needed to scrape issue: 8324.42 minutes
# 99893
# Issue added! Time needed to scrape issue: 8330.0 minutes
# 99960
# Issue added! Time needed to scrape issue: 8336.17 minutes
# 100034
# Issue added! Time needed to scrape issue: 8340.42 minutes
# 100085
# Issue added! Time needed to scrape issue: 8345.42 minutes
# 100145
# Issue added! Time needed to scrape issue: 8352.92 minutes
# 100235
# Issue added! Time needed to scrape issue: 8358.0 minutes
# 100296
# Issue added! Time needed to scrape issue: 8363.33 minutes
# 100360
# Issue added! Time needed to scrape issue: 8368.83 minutes
# 100426
# Issue added! Time needed to scrape issue: 8373.92 minutes
# 100487
# Issue added! Time needed to scrape issue: 8379.33 minutes
# 100552
# Issue added! Time needed to scrape issue: 8384.25 minutes
# 100611
# Issue added! Time needed to scrape issue: 8389.33 minutes
# 100672
# Issue added! Time needed to scrape issue: 8394.5 minutes
# 100734
# Issue added! Time needed to scrape issue: 8399.33 minutes
# 100792
# Issue added! Time needed to scrape issue: 8403.17 minutes
# 100838
# Issue added! Time needed to scrape issue: 8409.17 minutes
# 100910
# Issue added! Time needed to scrape issue: 8414.5 minutes
# 100974
# Issue added! Time needed to scrape issue: 8419.83 minutes
# 101038
# Issue added! Time needed to scrape issue: 8425.25 minutes
# 101103
# Issue added! Time needed to scrape issue: 8430.92 minutes
# 101171
# Issue added! Time needed to scrape issue: 8436.42 minutes
# 101237
# Issue added! Time needed to scrape issue: 8441.67 minutes
# 101300
# Issue added! Time needed to scrape issue: 8447.17 minutes
# 101366
# Issue added! Time needed to scrape issue: 8452.25 minutes
# 101427
# Issue added! Time needed to scrape issue: 8457.42 minutes
# 101489
# Issue added! Time needed to scrape issue: 8462.58 minutes
# 101551
# Issue added! Time needed to scrape issue: 8467.5 minutes
# 101610
# Issue added! Time needed to scrape issue: 8472.25 minutes
# 101667
# Issue added! Time needed to scrape issue: 8477.67 minutes
# 101732
# Issue added! Time needed to scrape issue: 8482.67 minutes
# 101792
# Issue added! Time needed to scrape issue: 8488.42 minutes
# 101861
# Issue added! Time needed to scrape issue: 8493.83 minutes
# 101926
# Issue added! Time needed to scrape issue: 8499.25 minutes
# 101991
# Issue added! Time needed to scrape issue: 8506.42 minutes
# 102077
# Issue added! Time needed to scrape issue: 8511.92 minutes
# 102143
# Issue added! Time needed to scrape issue: 8517.08 minutes
# 102205
# Issue added! Time needed to scrape issue: 8522.0 minutes
# 102264
# Issue added! Time needed to scrape issue: 8528.08 minutes
# 102337
# Issue added! Time needed to scrape issue: 8534.17 minutes
# 102410
# Issue added! Time needed to scrape issue: 8540.08 minutes
# 102481
# Issue added! Time needed to scrape issue: 8545.75 minutes
# 102549
# Issue added! Time needed to scrape issue: 8552.08 minutes
# 102625
# Issue added! Time needed to scrape issue: 8557.42 minutes
# 102689
# Issue added! Time needed to scrape issue: 8562.58 minutes
# 102751
# Issue added! Time needed to scrape issue: 8568.17 minutes
# 102818
# Issue added! Time needed to scrape issue: 8574.08 minutes
# 102889
# Issue added! Time needed to scrape issue: 8580.0 minutes
# 102960
# Issue added! Time needed to scrape issue: 8585.92 minutes
# 103031
# Issue added! Time needed to scrape issue: 8591.42 minutes
# 103097
# Issue added! Time needed to scrape issue: 8596.92 minutes
# 103163
# Issue added! Time needed to scrape issue: 8602.25 minutes
# 103227
# Issue added! Time needed to scrape issue: 8608.42 minutes
# 103301
# Issue added! Time needed to scrape issue: 8613.67 minutes
# 103364
# Issue added! Time needed to scrape issue: 8618.83 minutes
# 103426
# Issue added! Time needed to scrape issue: 8623.75 minutes
# 103485
# Issue added! Time needed to scrape issue: 8629.92 minutes
# 103559
# Issue added! Time needed to scrape issue: 8635.42 minutes
# 103625
# Issue added! Time needed to scrape issue: 8641.17 minutes
# 103694
# Issue added! Time needed to scrape issue: 8646.58 minutes
# 103759
# Issue added! Time needed to scrape issue: 8652.17 minutes
# 103826
# Issue added! Time needed to scrape issue: 8658.5 minutes
# 103902
# Issue added! Time needed to scrape issue: 8664.08 minutes
# 103969
# Issue added! Time needed to scrape issue: 8669.83 minutes
# 104038
# Issue added! Time needed to scrape issue: 8675.5 minutes
# 104106
# Issue added! Time needed to scrape issue: 8675.5 minutes
# 104106

# %%
# save article links to csv
print(len(article_list))

with open("article_links.csv", "w", encoding='UTF8', newline='') as f:
    writer = csv.writer(f)
    writer.writerows(article_list)
# Out:
# 104106

# %%
#article_list = article_list[:100]
data = {}
article_id = 1
for i in article_list:
    
    with urllib.request.urlopen(i[0]) as response:
       article = response.read()
    article_soup = BeautifulSoup(article, 'html.parser')
    ps = article_soup.findAll("p", class_=False)
    text = ""
    for p in ps:
        text += p.text
    article_data = {  
        "link": i[0],
        "date": article_soup.find("meta", {"name" : "date"})["content"],
        "keywords": article_soup.find("meta", {"name" : "news_keywords"})["content"],
        "author": article_soup.find("meta", {"name" : "author"})["content"],
        "title": i[1],
        "description": article_soup.find("meta", {"name" : "description"})["content"],
        "text": text
    }
    data[article_id] = article_data
    print("Artikel", article_id, "hinzugefügt")
    article_id += 1 
    if article_id == 100:
        break
    t.sleep(1)
# Out:
# Artikel 1 hinzugefügt
# Artikel 2 hinzugefügt
# Artikel 3 hinzugefügt
# Artikel 4 hinzugefügt
# Artikel 5 hinzugefügt
# Artikel 6 hinzugefügt
# Artikel 7 hinzugefügt
# Artikel 8 hinzugefügt
# Artikel 9 hinzugefügt
# Artikel 10 hinzugefügt
# Artikel 11 hinzugefügt
# Artikel 12 hinzugefügt
# Artikel 13 hinzugefügt
# Artikel 14 hinzugefügt
# Artikel 15 hinzugefügt
# Artikel 16 hinzugefügt
# Artikel 17 hinzugefügt
# Artikel 18 hinzugefügt
# Artikel 19 hinzugefügt
# Artikel 20 hinzugefügt
# Artikel 21 hinzugefügt
# Artikel 22 hinzugefügt
# Artikel 23 hinzugefügt
# Artikel 24 hinzugefügt
# Artikel 25 hinzugefügt
# Artikel 26 hinzugefügt
# Artikel 27 hinzugefügt
# Artikel 28 hinzugefügt
# Artikel 29 hinzugefügt
# Artikel 30 hinzugefügt
# Artikel 31 hinzugefügt
# Artikel 32 hinzugefügt
# Artikel 33 hinzugefügt
# Artikel 34 hinzugefügt
# Artikel 35 hinzugefügt
# Artikel 36 hinzugefügt
# Artikel 37 hinzugefügt
# Artikel 38 hinzugefügt
# Artikel 39 hinzugefügt
# Artikel 40 hinzugefügt
# Artikel 41 hinzugefügt
# Artikel 42 hinzugefügt
# Artikel 43 hinzugefügt
# Artikel 44 hinzugefügt
# Artikel 45 hinzugefügt
# Artikel 46 hinzugefügt
# Artikel 47 hinzugefügt
# Artikel 48 hinzugefügt
# Artikel 49 hinzugefügt
# Artikel 50 hinzugefügt
# Artikel 51 hinzugefügt
# Artikel 52 hinzugefügt
# Artikel 53 hinzugefügt
# Artikel 54 hinzugefügt
# Artikel 55 hinzugefügt
# Artikel 56 hinzugefügt
# Artikel 57 hinzugefügt
# Artikel 58 hinzugefügt
# Artikel 59 hinzugefügt
# Artikel 60 hinzugefügt
# Artikel 61 hinzugefügt
# Artikel 62 hinzugefügt
# Artikel 63 hinzugefügt
# Artikel 64 hinzugefügt
# Artikel 65 hinzugefügt
# Artikel 66 hinzugefügt
# Artikel 67 hinzugefügt
# Artikel 68 hinzugefügt
# Artikel 69 hinzugefügt
# Artikel 70 hinzugefügt
# Artikel 71 hinzugefügt
# Artikel 72 hinzugefügt
# Artikel 73 hinzugefügt
# Artikel 74 hinzugefügt
# Artikel 75 hinzugefügt
# Artikel 76 hinzugefügt
# Artikel 77 hinzugefügt
# Artikel 78 hinzugefügt
# Artikel 79 hinzugefügt
# Artikel 80 hinzugefügt
# Artikel 81 hinzugefügt
# Artikel 82 hinzugefügt
# Artikel 83 hinzugefügt
# Artikel 84 hinzugefügt
# Artikel 85 hinzugefügt
# Artikel 86 hinzugefügt
# Artikel 87 hinzugefügt
# Artikel 88 hinzugefügt
# Artikel 89 hinzugefügt
# Artikel 90 hinzugefügt
# Artikel 91 hinzugefügt
# Artikel 92 hinzugefügt
# Artikel 93 hinzugefügt
# Artikel 94 hinzugefügt
# Artikel 95 hinzugefügt
# Artikel 96 hinzugefügt
# Artikel 97 hinzugefügt
# Artikel 98 hinzugefügt
# Artikel 99 hinzugefügt

# %%
# save data into utf-8 json
with open('data.json', 'w', encoding='utf8') as f:
    json.dump(data, f, ensure_ascii=False)
